# %%
# Import the dependencies.
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=90248768a0a098f47e4d21e962f4c636

# %%
#Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_WeatherDesc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": city_WeatherDesc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | amuntai
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | aitape
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | jinji
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | batagay-alyta
# Processing Record 17 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | benito juarez
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | muros
# Processing Record 25 of Set 1 | palu
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | calvia
# Processing Record 28 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | toamasina
# Processing Record 32 of Set 1 | jiexiu
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | rockport
# Processing Record 37 of Set 1 | rio gallegos
# Processing Record 38 of Set 1 | coquimbo
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | portland
# Processing Record 41 of Set 1 | guerrero negro
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | lavrentiya
# Processing Record 46 of Set 1 | pangnirtung
# Processing Record 47 of Set 1 | port hawkesbury
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | acarau
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | landeck
# Processing Record 4 of Set 2 | kalmunai
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | diego de almagro
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | yinchuan
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 2 | acapulco
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | sioux lookout
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | cap malheureux
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | abu dhabi
# Processing Record 22 of Set 2 | kuminskiy
# Processing Record 23 of Set 2 | nea stira
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | garissa
# Processing Record 28 of Set 2 | fairmount
# Processing Record 29 of Set 2 | santa isabel do rio negro
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | najran
# Processing Record 32 of Set 2 | mount isa
# Processing Record 33 of Set 2 | ipameri
# Processing Record 34 of Set 2 | kungurtug
# Processing Record 35 of Set 2 | mayumba
# Processing Record 36 of Set 2 | nokaneng
# Processing Record 37 of Set 2 | laela
# Processing Record 38 of Set 2 | shitanjing
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | del rio
# Processing Record 41 of Set 2 | batagay
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | wieliczka
# Processing Record 44 of Set 2 | yokadouma
# Processing Record 45 of Set 2 | santo antonio do leverger
# Processing Record 46 of Set 2 | rawson
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | santa rosa
# Processing Record 2 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | amahai
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | givors
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | asahikawa
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | salalah
# Processing Record 16 of Set 3 | monduli
# Processing Record 17 of Set 3 | tymovskoye
# Processing Record 18 of Set 3 | guarapuava
# Processing Record 19 of Set 3 | carahue
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | saint-pierre
# Processing Record 22 of Set 3 | luancheng
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | beringovskiy
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | awbari
# Processing Record 27 of Set 3 | maumere
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | guanay
# Processing Record 30 of Set 3 | ponta delgada
# Processing Record 31 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | kitui
# Processing Record 36 of Set 3 | bardiyah
# Processing Record 37 of Set 3 | zhigansk
# Processing Record 38 of Set 3 | taoudenni
# Processing Record 39 of Set 3 | juneau
# Processing Record 40 of Set 3 | vao
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | alta floresta
# Processing Record 44 of Set 3 | mpika
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | buchanan
# Processing Record 1 of Set 4 | san anselmo
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | arman
# Processing Record 4 of Set 4 | verkhnevilyuysk
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | ventspils
# Processing Record 7 of Set 4 | kuvandyk
# Processing Record 8 of Set 4 | burnie
# Processing Record 9 of Set 4 | rocha
# Processing Record 10 of Set 4 | nuuk
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | buta
# Processing Record 13 of Set 4 | tuktoyaktuk
# Processing Record 14 of Set 4 | port keats
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | esso
# Processing Record 17 of Set 4 | buala
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | roswell
# Processing Record 20 of Set 4 | olafsvik
# Processing Record 21 of Set 4 | rocky mountain house
# Processing Record 22 of Set 4 | saint-georges
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | coahuayana
# Processing Record 25 of Set 4 | naryan-mar
# Processing Record 26 of Set 4 | westport
# Processing Record 27 of Set 4 | manokwari
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | khatanga
# Processing Record 30 of Set 4 | itoman
# Processing Record 31 of Set 4 | salimbalan
# Processing Record 32 of Set 4 | minab
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | sciacca
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | gizo
# Processing Record 37 of Set 4 | nisia floresta
# Processing Record 38 of Set 4 | redcar
# Processing Record 39 of Set 4 | brahmapuri
# City not found. Skipping...
# Processing Record 40 of Set 4 | nattam
# Processing Record 41 of Set 4 | fort nelson
# Processing Record 42 of Set 4 | voyvozh
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | ojinaga
# Processing Record 45 of Set 4 | asbestos
# Processing Record 46 of Set 4 | ust-koksa
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 48 of Set 4 | mankera
# Processing Record 49 of Set 4 | saint-philippe
# Processing Record 50 of Set 4 | san felipe
# Processing Record 1 of Set 5 | iquique
# Processing Record 2 of Set 5 | rajpipla
# Processing Record 3 of Set 5 | yumen
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | hay river
# Processing Record 6 of Set 5 | waipawa
# Processing Record 7 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 5 | saurimo
# Processing Record 12 of Set 5 | fort-shevchenko
# Processing Record 13 of Set 5 | gat
# Processing Record 14 of Set 5 | plettenberg bay
# Processing Record 15 of Set 5 | catuday
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | constitucion
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | lima
# Processing Record 20 of Set 5 | russell
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | jiangyou
# Processing Record 24 of Set 5 | nemuro
# Processing Record 25 of Set 5 | gboko
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | luganville
# Processing Record 29 of Set 5 | olinda
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 5 | isangel
# Processing Record 33 of Set 5 | ampanihy
# Processing Record 34 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 5 | port lincoln
# Processing Record 36 of Set 5 | okhotsk
# Processing Record 37 of Set 5 | hofn
# Processing Record 38 of Set 5 | kathu
# Processing Record 39 of Set 5 | biryusinsk
# Processing Record 40 of Set 5 | constantine
# Processing Record 41 of Set 5 | qaanaaq
# Processing Record 42 of Set 5 | liman
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | tuatapere
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | kamien pomorski
# Processing Record 47 of Set 5 | rio grande
# Processing Record 48 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 5 | scarborough
# Processing Record 50 of Set 5 | basco
# Processing Record 1 of Set 6 | sikonge
# Processing Record 2 of Set 6 | san fernando
# Processing Record 3 of Set 6 | bonga
# Processing Record 4 of Set 6 | mildura
# Processing Record 5 of Set 6 | mansa
# Processing Record 6 of Set 6 | lumeje
# Processing Record 7 of Set 6 | kismayo
# Processing Record 8 of Set 6 | felipe carrillo puerto
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | hanting
# Processing Record 11 of Set 6 | birao
# Processing Record 12 of Set 6 | tabuk
# Processing Record 13 of Set 6 | bayanday
# Processing Record 14 of Set 6 | hobyo
# Processing Record 15 of Set 6 | ouranopolis
# City not found. Skipping...
# Processing Record 16 of Set 6 | kisangani
# Processing Record 17 of Set 6 | mar del plata
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | yola
# Processing Record 20 of Set 6 | linxia
# Processing Record 21 of Set 6 | radomsko
# Processing Record 22 of Set 6 | banda aceh
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | ngunguru
# Processing Record 25 of Set 6 | benguela
# Processing Record 26 of Set 6 | haines junction
# Processing Record 27 of Set 6 | jalu
# Processing Record 28 of Set 6 | lebu
# Processing Record 29 of Set 6 | le vauclin
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | chapais
# Processing Record 32 of Set 6 | zhigalovo
# Processing Record 33 of Set 6 | chenghai
# Processing Record 34 of Set 6 | kapchorwa
# Processing Record 35 of Set 6 | ulladulla
# Processing Record 36 of Set 6 | shepsi
# Processing Record 37 of Set 6 | airai
# Processing Record 38 of Set 6 | halifax
# Processing Record 39 of Set 6 | vardo
# Processing Record 40 of Set 6 | sunbury
# Processing Record 41 of Set 6 | moron
# Processing Record 42 of Set 6 | langham
# Processing Record 43 of Set 6 | havelock
# Processing Record 44 of Set 6 | vung tau
# Processing Record 45 of Set 6 | acajutla
# Processing Record 46 of Set 6 | saint-augustin
# Processing Record 47 of Set 6 | fukue
# Processing Record 48 of Set 6 | safford
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | chifeng
# Processing Record 1 of Set 7 | copiapo
# Processing Record 2 of Set 7 | lopsmarka
# Processing Record 3 of Set 7 | yaan
# Processing Record 4 of Set 7 | praia da vitoria
# Processing Record 5 of Set 7 | cidreira
# Processing Record 6 of Set 7 | karangampel
# Processing Record 7 of Set 7 | burica
# City not found. Skipping...
# Processing Record 8 of Set 7 | njeru
# Processing Record 9 of Set 7 | oktyabrskiy
# Processing Record 10 of Set 7 | keetmanshoop
# Processing Record 11 of Set 7 | avera
# Processing Record 12 of Set 7 | college
# Processing Record 13 of Set 7 | guaymas
# Processing Record 14 of Set 7 | souillac
# Processing Record 15 of Set 7 | duldurga
# Processing Record 16 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | khasan
# Processing Record 20 of Set 7 | linjiang
# Processing Record 21 of Set 7 | takehara
# Processing Record 22 of Set 7 | houma
# Processing Record 23 of Set 7 | maslovare
# Processing Record 24 of Set 7 | terrace bay
# Processing Record 25 of Set 7 | votkinsk
# Processing Record 26 of Set 7 | yamada
# Processing Record 27 of Set 7 | klyuchi
# Processing Record 28 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 7 | te anau
# Processing Record 30 of Set 7 | walvis bay
# Processing Record 31 of Set 7 | shirokiy
# Processing Record 32 of Set 7 | at-bashi
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | aguimes
# Processing Record 35 of Set 7 | kagoro
# Processing Record 36 of Set 7 | port barton
# Processing Record 37 of Set 7 | norfolk
# Processing Record 38 of Set 7 | san cristobal
# Processing Record 39 of Set 7 | tarakan
# Processing Record 40 of Set 7 | itarema
# Processing Record 41 of Set 7 | tagusao
# Processing Record 42 of Set 7 | clyde river
# Processing Record 43 of Set 7 | taft
# Processing Record 44 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 7 | karaton
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | letlhakane
# Processing Record 48 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 7 | bentiu
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | malakal
# Processing Record 2 of Set 8 | bakchar
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | arraial do cabo
# Processing Record 5 of Set 8 | peruibe
# Processing Record 6 of Set 8 | kingaroy
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | shiyan
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | deseronto
# Processing Record 11 of Set 8 | ixtapa
# Processing Record 12 of Set 8 | mackay
# Processing Record 13 of Set 8 | phan thiet
# Processing Record 14 of Set 8 | meulaboh
# Processing Record 15 of Set 8 | boa vista
# Processing Record 16 of Set 8 | port blair
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | prince rupert
# Processing Record 19 of Set 8 | corvallis
# Processing Record 20 of Set 8 | caravelas
# Processing Record 21 of Set 8 | mutis
# Processing Record 22 of Set 8 | aksarka
# Processing Record 23 of Set 8 | salinopolis
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | kidal
# Processing Record 26 of Set 8 | ouesso
# Processing Record 27 of Set 8 | chokurdakh
# Processing Record 28 of Set 8 | barraute
# Processing Record 29 of Set 8 | sao filipe
# Processing Record 30 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 31 of Set 8 | potoci
# Processing Record 32 of Set 8 | bandarbeyla
# Processing Record 33 of Set 8 | harper
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | bedele
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | dolinsk
# Processing Record 38 of Set 8 | canton
# Processing Record 39 of Set 8 | qandala
# Processing Record 40 of Set 8 | kanaya
# Processing Record 41 of Set 8 | kawalu
# Processing Record 42 of Set 8 | burton
# Processing Record 43 of Set 8 | sobolevo
# Processing Record 44 of Set 8 | charlottetown
# Processing Record 45 of Set 8 | sulangan
# Processing Record 46 of Set 8 | gambela
# Processing Record 47 of Set 8 | kytmanovo
# Processing Record 48 of Set 8 | labuhan
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 9 | puerto palomas
# Processing Record 2 of Set 9 | kahului
# Processing Record 3 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 9 | goderich
# Processing Record 5 of Set 9 | klaksvik
# Processing Record 6 of Set 9 | medyn
# Processing Record 7 of Set 9 | bad salzungen
# Processing Record 8 of Set 9 | ust-tsilma
# Processing Record 9 of Set 9 | husavik
# Processing Record 10 of Set 9 | todos santos
# Processing Record 11 of Set 9 | coihueco
# Processing Record 12 of Set 9 | dali
# Processing Record 13 of Set 9 | kobryn
# Processing Record 14 of Set 9 | shingu
# Processing Record 15 of Set 9 | santa maria
# Processing Record 16 of Set 9 | bonavista
# Processing Record 17 of Set 9 | balsas
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 9 | hamilton
# Processing Record 21 of Set 9 | kot diji
# Processing Record 22 of Set 9 | sao joao da barra
# Processing Record 23 of Set 9 | svit
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | sompeta
# Processing Record 26 of Set 9 | faya
# Processing Record 27 of Set 9 | baglan
# Processing Record 28 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 9 | alugan
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | sinnamary
# Processing Record 32 of Set 9 | mahibadhoo
# Processing Record 33 of Set 9 | golden
# Processing Record 34 of Set 9 | udachnyy
# Processing Record 35 of Set 9 | karratha
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | bandar-e anzali
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | sudogda
# Processing Record 40 of Set 9 | ust-shonosha
# Processing Record 41 of Set 9 | mecca
# Processing Record 42 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 9 | nizhnevartovsk
# Processing Record 44 of Set 9 | yazman
# Processing Record 45 of Set 9 | salamanca
# Processing Record 46 of Set 9 | kuusamo
# Processing Record 47 of Set 9 | koudougou
# Processing Record 48 of Set 9 | visby
# Processing Record 49 of Set 9 | suchilquitongo
# City not found. Skipping...
# Processing Record 50 of Set 9 | port hardy
# Processing Record 1 of Set 10 | alice springs
# Processing Record 2 of Set 10 | jumla
# Processing Record 3 of Set 10 | pierre
# Processing Record 4 of Set 10 | port-cartier
# Processing Record 5 of Set 10 | vila
# Processing Record 6 of Set 10 | tortona
# Processing Record 7 of Set 10 | oistins
# Processing Record 8 of Set 10 | zyryanovsk
# Processing Record 9 of Set 10 | baghdad
# Processing Record 10 of Set 10 | sammamish
# Processing Record 11 of Set 10 | kuryk
# Processing Record 12 of Set 10 | afyonkarahisar
# Processing Record 13 of Set 10 | huoqiu
# Processing Record 14 of Set 10 | coruripe
# Processing Record 15 of Set 10 | ruteng
# Processing Record 16 of Set 10 | chara
# Processing Record 17 of Set 10 | bam
# Processing Record 18 of Set 10 | taikang
# Processing Record 19 of Set 10 | luderitz
# Processing Record 20 of Set 10 | vanimo
# Processing Record 21 of Set 10 | grindavik
# Processing Record 22 of Set 10 | harbin
# Processing Record 23 of Set 10 | horana
# Processing Record 24 of Set 10 | weinan
# Processing Record 25 of Set 10 | wageningen
# Processing Record 26 of Set 10 | buin
# Processing Record 27 of Set 10 | west bay
# Processing Record 28 of Set 10 | gorontalo
# Processing Record 29 of Set 10 | codrington
# Processing Record 30 of Set 10 | arkhangelsk
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | zhangjiakou
# Processing Record 33 of Set 10 | bulgan
# Processing Record 34 of Set 10 | pampa
# Processing Record 35 of Set 10 | cayenne
# Processing Record 36 of Set 10 | narwar
# Processing Record 37 of Set 10 | sivaki
# Processing Record 38 of Set 10 | treinta y tres
# Processing Record 39 of Set 10 | ostrovnoy
# Processing Record 40 of Set 10 | mahebourg
# Processing Record 41 of Set 10 | aripuana
# Processing Record 42 of Set 10 | srednekolymsk
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | irbil
# Processing Record 45 of Set 10 | iberia
# Processing Record 46 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 47 of Set 10 | vila do maio
# Processing Record 48 of Set 10 | bhinmal
# Processing Record 49 of Set 10 | pataskala
# Processing Record 50 of Set 10 | malazgirt
# Processing Record 1 of Set 11 | paamiut
# Processing Record 2 of Set 11 | maceio
# Processing Record 3 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | storslett
# Processing Record 6 of Set 11 | big spring
# Processing Record 7 of Set 11 | hastings
# Processing Record 8 of Set 11 | kilifi
# Processing Record 9 of Set 11 | khilok
# Processing Record 10 of Set 11 | nata
# Processing Record 11 of Set 11 | wilmington
# Processing Record 12 of Set 11 | fairview
# Processing Record 13 of Set 11 | canora
# Processing Record 14 of Set 11 | inhambane
# Processing Record 15 of Set 11 | damghan
# Processing Record 16 of Set 11 | hillsborough
# Processing Record 17 of Set 11 | kosh-agach
# Processing Record 18 of Set 11 | wakefield
# Processing Record 19 of Set 11 | rancho palos verdes
# Processing Record 20 of Set 11 | wanxian
# Processing Record 21 of Set 11 | imeni poliny osipenko
# Processing Record 22 of Set 11 | honiara
# Processing Record 23 of Set 11 | antofagasta
# Processing Record 24 of Set 11 | foam lake
# Processing Record 25 of Set 11 | okitipupa
# Processing Record 26 of Set 11 | ambulu
# Processing Record 27 of Set 11 | belmonte
# Processing Record 28 of Set 11 | sandwick
# Processing Record 29 of Set 11 | ahipara
# Processing Record 30 of Set 11 | gisborne
# Processing Record 31 of Set 11 | ukiah
# Processing Record 32 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 11 | tatsinskaya
# City not found. Skipping...
# Processing Record 34 of Set 11 | benjamin aceval
# Processing Record 35 of Set 11 | pontes e lacerda
# Processing Record 36 of Set 11 | viedma
# Processing Record 37 of Set 11 | chicama
# Processing Record 38 of Set 11 | vilcun
# Processing Record 39 of Set 11 | vaitape
# Processing Record 40 of Set 11 | santa cruz
# Processing Record 41 of Set 11 | kuching
# Processing Record 42 of Set 11 | ypsonas
# Processing Record 43 of Set 11 | vila velha
# Processing Record 44 of Set 11 | tshane
# Processing Record 45 of Set 11 | gamba
# Processing Record 46 of Set 11 | along
# Processing Record 47 of Set 11 | chauk
# Processing Record 48 of Set 11 | yanam
# Processing Record 49 of Set 11 | touros
# Processing Record 50 of Set 11 | egvekinot
# Processing Record 1 of Set 12 | portel
# Processing Record 2 of Set 12 | karpathos
# Processing Record 3 of Set 12 | bedesa
# Processing Record 4 of Set 12 | zhetybay
# City not found. Skipping...
# Processing Record 5 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 12 | merauke
# Processing Record 7 of Set 12 | gunnedah
# Processing Record 8 of Set 12 | manaus
# Processing Record 9 of Set 12 | balikpapan
# Processing Record 10 of Set 12 | cabedelo
# Processing Record 11 of Set 12 | tual
# Processing Record 12 of Set 12 | high level
# Processing Record 13 of Set 12 | surt
# Processing Record 14 of Set 12 | kasane
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | hubli
# Processing Record 17 of Set 12 | sankt andra
# City not found. Skipping...
# Processing Record 18 of Set 12 | concordia
# Processing Record 19 of Set 12 | beloha
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | antsohihy
# Processing Record 22 of Set 12 | dehui
# Processing Record 23 of Set 12 | mlonggo
# Processing Record 24 of Set 12 | talara
# Processing Record 25 of Set 12 | chiredzi
# Processing Record 26 of Set 12 | ondo
# Processing Record 27 of Set 12 | corinth
# Processing Record 28 of Set 12 | masuguru
# Processing Record 29 of Set 12 | dakar
# Processing Record 30 of Set 12 | parvatipuram
# Processing Record 31 of Set 12 | marienburg
# Processing Record 32 of Set 12 | kavieng
# Processing Record 33 of Set 12 | brae
# Processing Record 34 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 35 of Set 12 | skjervoy
# Processing Record 36 of Set 12 | kibaya
# Processing Record 37 of Set 12 | amsterdam
# Processing Record 38 of Set 12 | christchurch
# Processing Record 39 of Set 12 | kaliyaganj
# Processing Record 40 of Set 12 | kieta
# Processing Record 41 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 12 | belyy yar
# Processing Record 43 of Set 12 | rovaniemi
# Processing Record 44 of Set 12 | kaitong
# Processing Record 45 of Set 12 | emerald
# Processing Record 46 of Set 12 | kuytun
# Processing Record 47 of Set 12 | frunzivka
# Processing Record 48 of Set 12 | springdale
# Processing Record 49 of Set 12 | sitia
# Processing Record 50 of Set 12 | luis correia
# Processing Record 1 of Set 13 | mogocha
# Processing Record 2 of Set 13 | cockburn town
# Processing Record 3 of Set 13 | mbacke
# City not found. Skipping...
# Processing Record 4 of Set 13 | katherine
# Processing Record 5 of Set 13 | phalaborwa
# Processing Record 6 of Set 13 | odweyne
# Processing Record 7 of Set 13 | taiyuan
# Processing Record 8 of Set 13 | tabas
# Processing Record 9 of Set 13 | chulym
# Processing Record 10 of Set 13 | lapua
# Processing Record 11 of Set 13 | nouadhibou
# Processing Record 12 of Set 13 | algarrobo
# Processing Record 13 of Set 13 | nantucket
# Processing Record 14 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 13 | birjand
# Processing Record 16 of Set 13 | alexandria
# Processing Record 17 of Set 13 | kenai
# Processing Record 18 of Set 13 | biak
# Processing Record 19 of Set 13 | sorland
# Processing Record 20 of Set 13 | caarapo
# Processing Record 21 of Set 13 | manassas
# Processing Record 22 of Set 13 | kununurra
# Processing Record 23 of Set 13 | macaubas
# Processing Record 24 of Set 13 | anadyr
# Processing Record 25 of Set 13 | puerto carreno
# Processing Record 26 of Set 13 | waddan
# Processing Record 27 of Set 13 | zeya
# Processing Record 28 of Set 13 | pirovskoye
# Processing Record 29 of Set 13 | bo
# City not found. Skipping...
# Processing Record 30 of Set 13 | denpasar
# Processing Record 31 of Set 13 | valparaiso
# Processing Record 32 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 13 | ambilobe
# Processing Record 34 of Set 13 | conde
# Processing Record 35 of Set 13 | camacha
# Processing Record 36 of Set 13 | honningsvag
# Processing Record 37 of Set 13 | luwuk
# Processing Record 38 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 39 of Set 13 | coihaique
# Processing Record 40 of Set 13 | laguna
# Processing Record 41 of Set 13 | samarai
# Processing Record 42 of Set 13 | huarmey
# Processing Record 43 of Set 13 | caraquet
# Processing Record 44 of Set 13 | hyeres
# Processing Record 45 of Set 13 | port hedland
# Processing Record 46 of Set 13 | taloqan
# Processing Record 47 of Set 13 | bubaque
# Processing Record 48 of Set 13 | tomatlan
# Processing Record 49 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 50 of Set 13 | ferme-neuve
# Processing Record 1 of Set 14 | puerto del rosario
# Processing Record 2 of Set 14 | marsabit
# Processing Record 3 of Set 14 | oranjestad
# Processing Record 4 of Set 14 | asheville
# Processing Record 5 of Set 14 | eydhafushi
# Processing Record 6 of Set 14 | dubrovnik
# Processing Record 7 of Set 14 | wanning
# Processing Record 8 of Set 14 | jaru
# Processing Record 9 of Set 14 | mana
# Processing Record 10 of Set 14 | maneadero
# Processing Record 11 of Set 14 | kruisfontein
# Processing Record 12 of Set 14 | deputatskiy
# Processing Record 13 of Set 14 | seryshevo
# Processing Record 14 of Set 14 | jardim
# Processing Record 15 of Set 14 | invermere
# Processing Record 16 of Set 14 | abu samrah
# Processing Record 17 of Set 14 | aswan
# Processing Record 18 of Set 14 | san carlos de bariloche
# Processing Record 19 of Set 14 | ayan
# Processing Record 20 of Set 14 | tacna
# Processing Record 21 of Set 14 | vanavara
# Processing Record 22 of Set 14 | zheleznodorozhnyy
# Processing Record 23 of Set 14 | innisfail
# Processing Record 24 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 14 | kemijarvi
# Processing Record 26 of Set 14 | gunjur
# Processing Record 27 of Set 14 | san vicente
# Processing Record 28 of Set 14 | shenzhen
# Processing Record 29 of Set 14 | bangassou
# Processing Record 30 of Set 14 | sayabec
# City not found. Skipping...
# Processing Record 31 of Set 14 | kautokeino
# Processing Record 32 of Set 14 | binzhou
# Processing Record 33 of Set 14 | middleton
# Processing Record 34 of Set 14 | pelym
# Processing Record 35 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 14 | kutum
# Processing Record 37 of Set 14 | pundaguitan
# Processing Record 38 of Set 14 | bemidji
# Processing Record 39 of Set 14 | grand gaube
# Processing Record 40 of Set 14 | hearst
# Processing Record 41 of Set 14 | talnakh
# Processing Record 42 of Set 14 | bonfim
# Processing Record 43 of Set 14 | pingliang
# Processing Record 44 of Set 14 | culfa
# Processing Record 45 of Set 14 | kurilsk
# Processing Record 46 of Set 14 | nhulunbuy
# Processing Record 47 of Set 14 | peniche
# Processing Record 48 of Set 14 | ambon
# Processing Record 49 of Set 14 | tando adam
# Processing Record 50 of Set 14 | terney
# Processing Record 1 of Set 15 | san matias
# Processing Record 2 of Set 15 | ozernovskiy
# Processing Record 3 of Set 15 | lamu
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | yarim
# Processing Record 6 of Set 15 | shambu
# Processing Record 7 of Set 15 | bijie
# Processing Record 8 of Set 15 | groningen
# Processing Record 9 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 15 | villa carlos paz
# Processing Record 11 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 12 of Set 15 | hargeysa
# Processing Record 13 of Set 15 | sabya
# Processing Record 14 of Set 15 | nicolas bravo
# Processing Record 15 of Set 15 | ziyang
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | neapolis
# Processing Record 18 of Set 15 | bideford
# Processing Record 19 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 15 | luba
# Processing Record 21 of Set 15 | general jose eduvigis diaz
# Processing Record 22 of Set 15 | ulaanbaatar
# Processing Record 23 of Set 15 | gravdal
# Processing Record 24 of Set 15 | yoichi
# Processing Record 25 of Set 15 | banamba
# Processing Record 26 of Set 15 | dhule
# Processing Record 27 of Set 15 | lashio
# Processing Record 28 of Set 15 | kentau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng Weather Description  Max Temp  Humidity  \
# 0     San Patricio  28.0170  -97.5169     overcast clouds     71.60        88
# 1          Amuntai  -2.4177  115.2494    scattered clouds     91.42        49
# 2      Port Alfred -33.5906   26.8910           clear sky     66.25        81
# 3   Ribeira Grande  38.5167  -28.7000          few clouds     56.84        74
# 4           Aitape  -3.1374  142.3475     overcast clouds     84.34        72
# 5   Cabo San Lucas  22.8909 -109.9124    scattered clouds     77.00        33
# 6       Kaitangata -46.2817  169.8464     overcast clouds     59.00        73
# 7  Bambous Virieux -20.3428   57.7575          light rain     73.99       100
# 8        Cape Town -33.9258   18.4232          few clouds     57.00       100
# 9            Kapaa  22.0752 -159.3190    scattered clouds     78.80        69
#
#    Cloudiness  Wind Speed Country
# 0          90       13.80      US
# 1          33        1.54      ID
# 2           0       19.53      ZA
# 3          13       35.70      PT
# 4         100        6.04      PG
# 5          40       11.50      MX
# 6         100        1.01      NZ
# 7          75        3.44      MU
# 8          20       11.50      ZA
# 9          40        8.05      US

# %%
# Re-order columns of the dataframe
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     San Patricio      US  28.0170  -97.5169     71.60        88          90
# 1          Amuntai      ID  -2.4177  115.2494     91.42        49          33
# 2      Port Alfred      ZA -33.5906   26.8910     66.25        81           0
# 3   Ribeira Grande      PT  38.5167  -28.7000     56.84        74          13
# 4           Aitape      PG  -3.1374  142.3475     84.34        72         100
# 5   Cabo San Lucas      MX  22.8909 -109.9124     77.00        33          40
# 6       Kaitangata      NZ -46.2817  169.8464     59.00        73         100
# 7  Bambous Virieux      MU -20.3428   57.7575     73.99       100          75
# 8        Cape Town      ZA -33.9258   18.4232     57.00       100          20
# 9            Kapaa      US  22.0752 -159.3190     78.80        69          40
#
#    Wind Speed Weather Description
# 0       13.80     overcast clouds
# 1        1.54    scattered clouds
# 2       19.53           clear sky
# 3       35.70          few clouds
# 4        6.04     overcast clouds
# 5       11.50    scattered clouds
# 6        1.01     overcast clouds
# 7        3.44          light rain
# 8       11.50          few clouds
# 9        8.05    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
